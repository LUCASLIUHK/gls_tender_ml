# %% [markdown]
# # Zone & Region

# %%
import pandas as pd
import numpy as np
import re
import string
import os
import pdfplumber
from typing import List

# %% [markdown]
# ## Try using project name

# %%
geo = pd.read_csv("reference_table.csv")
gls = pd.read_csv("gls_full.csv")
header_gls = list(gls.columns)

# %% [markdown]
# ### Fill in project names

# %%
gls.proj_name_raw[gls.proj_name_raw.isna()]
# Out:
# 71     NaN
# 121    NaN
# 122    NaN
# 123    NaN
# 143    NaN
#       ...
# 591    NaN
# 592    NaN
# 593    NaN
# 594    NaN
# 595    NaN
# Name: proj_name_raw, Length: 346, dtype: object

# %%
# once-for-all
def parse_text(text_containing_land_parcel: str)-> str:
    pattern1 = r'(.*?)\('
    pattern2 = r'\((.*?)\)'

    try:
        found_proj = '-'.join(re.findall(pattern1, text_containing_land_parcel)[0].strip().lower().split(' '))
        found_land = re.findall(pattern2, text_containing_land_parcel)[0].strip()
    except:
        found_proj = np.nan
        found_land = np.nan

    return found_proj, found_land


file_list = os.listdir(r'G:\REA\Working files\land-bidding\ura_scrape\sg land bidding\tender details')
parsed_names = list(map(parse_text, file_list))
more_proj = pd.DataFrame({'proj_name_raw_1': [item[0] for item in parsed_names],
                          'land_parcel': [item[1] for item in parsed_names]})
# more_proj.to_csv("more_proj.csv")

# %% [markdown]
# ### Merge by project name

# %%
gls = pd.merge(gls, geo, how='left', left_on='proj_name_res', right_on='project_name')
gls_merged1 = gls[["land_parcel", "street", "zone", "region", "proj_name_res", "project_name"]]
gls.rename(columns={'zone': 'zone_by_proj', 'region': 'region_by_proj'}, inplace=True)
gls_merged1.isna().sum()
# Out:
# land_parcel        0
# street             0
# zone             406
# region           406
# proj_name_res    349
# project_name     406
# dtype: int64

# %% [markdown]
# ## Try using land parcel name

# %%
zone_region = geo[["zone", "region"]].drop_duplicates()

land_zone = gls.land_parcel.apply(lambda x: ' '.join(x.lower().split(' ')[:-1]))
gls.insert(loc=list(gls.columns).index("land_parcel")+1, column="zone_formatted", value=land_zone.values)
land_zone_distinct = pd.DataFrame(land_zone.unique(), columns=["zone"])

# %%
# funcs to identify zone names
def match_score(dictionary: str, lookup_value: str):
    if lookup_value:
        a = list("".join(dictionary.split(" ")))
        b = list("".join(lookup_value.split(" ")))
        score_a = 0
        score_b = 0
        penalty_a = 0
        penalty_b = 0
        total_len_a = len(a)
        total_len_b = len(b)
        if total_len_a * total_len_b > 0:
            for char in a:
                if char in b:
                    score_a += 1
                else:
                    penalty_a += 1
            for char in b:
                if char in a:
                    score_b += 1
                else:
                    penalty_b += 1
            return (score_a / total_len_a) * (score_b / total_len_b) - (penalty_a / total_len_a) * (penalty_b / total_len_b)
        else:
            return np.nan

    else:
        return np.nan


def order_score(dictionary: str, lookup_value: str):
    char_list_dict = list(dictionary)
    charset_dict = list(set(char_list_dict))
    order_dict_a = dict()
    for char in charset_dict:
        order_dict_a[char] = char_list_dict.index(char)

    char_list_value = list(lookup_value)
    charset_value = list(set(char_list_value))
    order_dict_b = dict()
    for char in charset_value:
        order_dict_b[char] = char_list_value.index(char)

    # get the index of first char of dict in value dict
    first_char = dictionary[0]

    try:
        first_char_idx = order_dict_b[first_char]
        # print(first_char_idx)
        # recalculate index for value dict
        for char in order_dict_b.keys():
            order_dict_b[char] -= first_char_idx

    except KeyError:
        pass

    char_order_dict = [order_dict_a.get(key) for key in char_list_dict]
    char_order_dict_in_value = [order_dict_b.get(key) for key in char_list_dict]

    # calculate variation score
    sum_ = 0
    len_ = 0
    for k in range(len(char_order_dict)):
        if char_order_dict_in_value[k] is None:
            sum_ += 1
        else:
            sum_ += (char_order_dict[k] - char_order_dict_in_value[k]) ** 2
        len_ += 1

    try:
        variation = (sum_ / len_) ** 0.5
    except ZeroDivisionError:
        variation = np.nan

    return variation


def name_match(name: str, dictionary, limit=None):
    # zone = region_na.zone.reset_index(drop=True)[7]
    # dictionary = pd.DataFrame(dictionary)
    match_score_list = dictionary.apply(match_score, lookup_value=name)
    order_score_list = dictionary.apply(order_score, lookup_value=name)
    max_order_var = order_score_list.max()
    min_order_var = order_score_list.min()
    order_var_range = max_order_var - min_order_var
    if order_var_range:
        order_score_list = order_score_list.apply(lambda x: (max_order_var - x)/order_var_range)
    else:
        order_score_list = order_score_list.apply(lambda x: np.nan)
    matched_df = pd.DataFrame({"std_name": dictionary.values, f"{name}_match": match_score_list, f"{name}_order": order_score_list})
    matched_df["compound_score"] = matched_df[f"{name}_match"] * matched_df[f"{name}_order"]
    sorted_matched_df = matched_df.sort_values(by="compound_score", ascending=False)
    sorted_matched_df.reset_index(drop=True, inplace=True)
    best_matched = sorted_matched_df.std_name[0]
    best_matched_score = sorted_matched_df.compound_score[0]
    if limit:
        return (best_matched, best_matched_score) if best_matched_score >= limit else (np.nan, best_matched_score)
    return best_matched, best_matched_score
    # return sorted_matched_df


def clean_street_name(street: str)-> str:
    suffix = ['street', 'st', 'road', 'rd', 'avenue', 'ave', 'crescent', 'drive', 'dr', 'boulevard', 'blvd', 'rise', 'way', 'lane', 'alley', 'link', 'walk', 'vista', 'track', 'vale']
    prefix = ['upper', 'lower']
    news = ['north', 'east', 'west', 'north']
    street = street.lower()
    street = re.sub(r'/', ' ', street)
    street = ''.join([char for char in list(street) if char not in string.punctuation])

    street = re.sub(r'\d+', '', street)
    street = re.sub(r' +', ' ', street).strip()
    st_list = street.split(' ')

    if ' '.join(st_list) != 'bukit drive':
        # check prefix
        if st_list[0] in prefix:
            st_list = st_list[1:]

        # check suffix & direction: 'direction+suffix' format
        if st_list[-1] in suffix:
            st_list = st_list[:-1]
            if st_list[-1] in news and len(st_list) > 1 and st_list[-2] != 'jurong':
                    st_list = st_list[:-1]
        elif st_list[-1] in news and len(st_list) > 1 and st_list[-2] != 'jurong':
            st_list = st_list[:-1]
            if st_list[-1] in suffix:
                st_list = st_list[:-1]
        return ' '.join(st_list)
    else:
        return 'bukit drive'


def st_name_match(name: str, ref_df, key):
    key_list = list(ref_df[key])
    matched = np.nan
    for i in range(len(key_list)):
        check = key_list[i]
        if key_list[i] == name:
            matched = key_list[i]
            break
    if pd.isna(matched):
        for i in range(len(key_list)):
            if key_list[i] in name:
                matched = key_list[i]
                break
    return matched

# %%
gls.insert(loc=list(gls.columns).index("zone_formatted")+1, column="zone_guess", value=gls.zone_formatted.apply(name_match, dictionary=zone_region.zone, limit=0.6).apply(lambda x: x[0]))
gls
# Out:
#                                              sg_gls_id date_launch  \
# 0    8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 1    f2e43515a8e783bc2314727cb58587c8ee761ab7a4a016...   29/4/2015
# 2    384815dd4cafcbf88b2f11099d8bced7a584736ec36742...  30/12/2013
# 3    05c11060bf1cbcb2db7aa3ed898c19a09fd298c3b1c3a4...   15/4/2013
# 4    d9fcb7d323ca5b77f6a22635200afafdd99e67f6feb109...   28/2/2013
# ..                                                 ...         ...
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...  19/10/1992
# 592  40e8902a48c5f3b717a76c37e270d2360da9e1172da322...  19/10/1992
# 593  43e84a0ed4744cddede5fb08c7162e61eb86cdf7b7823d...  19/10/1992
# 594  473d6c80a232fc34e07f2a9ef544b66270d175537468eb...   31/8/1992
# 595  50895000069c66ef0605e7f5fc87b07ecbbb602ea102ff...   31/8/1992
#
#      date_close date_award                              land_parcel  \
# 0     23/6/2015  30/6/2015                           Queenstown S9b
# 1     18/6/2015  23/6/2015                             Toa Payoh S4
# 2     29/4/2014  30/4/2014                               Geylang S6
# 3     13/6/2013  14/6/2013                             Sengkang S12
# 4     11/4/2013  12/4/2013                             Sengkang S11
# ..          ...        ...                                      ...
# 591    9/2/1993  21/5/1993                               Kaki Bukit
# 592    9/2/1993  21/5/1993  Tuas South Avenue 3/Tuas South Avenue 4
# 593    9/2/1993  21/5/1993  Tuas South Avenue 4/Tuas South Avenue 5
# 594  24/11/1992  15/2/1993               Merchant Road/Angus Street
# 595  24/11/1992  15/2/1993              Merchant Road/Magazine Road
#
#                             zone_formatted  zone_guess  \
# 0                               queenstown  queenstown
# 1                                toa payoh   toa payoh
# 2                                  geylang     geylang
# 3                                 sengkang    sengkang
# 4                                 sengkang    sengkang
# ..                                     ...         ...
# 591                                   kaki         NaN
# 592  tuas south avenue 3/tuas south avenue         NaN
# 593  tuas south avenue 4/tuas south avenue         NaN
# 594                    merchant road/angus         NaN
# 595                 merchant road/magazine         NaN
#
#                                       street  site_area_sqm   devt_type  ...  \
# 0                                Dundee Road        10516.1         *CO  ...
# 1      Lorong 6 Toa Payoh/Lorong 4 Toa Payoh        12154.6         *CO  ...
# 2                                 Sims Drive        23900.1         *CO  ...
# 3                             Fernvale Close        14930.5         *CO  ...
# 4                          Sengkang West Way        16603.9         *CO  ...
# ..                                       ...            ...         ...  ...
# 591                               Kaki Bukit        60000.0  Industrial  ...
# 592  Tuas South Avenue 3/Tuas South Avenue 4       102264.0  Industrial  ...
# 593  Tuas South Avenue 4/Tuas South Avenue 5       102264.0  Industrial  ...
# 594               Merchant Road/Angus Street         2609.0       Hotel  ...
# 595              Merchant Road/Magazine Road         4806.0  Commercial  ...
#
#     month_close  day_close  award_month_index  year_award  month_award  \
# 0             6         23             201506        2015            6
# 1             6         18             201506        2015            6
# 2             4         29             201404        2014            4
# 3             6         13             201306        2013            6
# 4             4         11             201304        2013            4
# ..          ...        ...                ...         ...          ...
# 591           2          9             199305        1993            5
# 592           2          9             199305        1993            5
# 593           2          9             199305        1993            5
# 594          11         24             199302        1993            2
# 595          11         24             199302        1993            2
#
#      day_award           project_name     region_by_proj  zone_by_proj  \
# 0           30            queens-peak     central region    queenstown
# 1           23         gem-residences     central region     toa payoh
# 2           30       sims-urban-oasis     central region       geylang
# 3           14  rivertrees-residences  north-east region      sengkang
# 4           12  riverbank-at-fernvale  north-east region      sengkang
# ..         ...                    ...                ...           ...
# 591         21                    NaN                NaN           NaN
# 592         21                    NaN                NaN           NaN
# 593         21                    NaN                NaN           NaN
# 594         15                    NaN                NaN           NaN
# 595         15                    NaN                NaN           NaN
#
#          address_street
# 0           dundee road
# 1    lorong 5 toa payoh
# 2            sims drive
# 3        fernvale close
# 4        fernvale close
# ..                  ...
# 591                 NaN
# 592                 NaN
# 593                 NaN
# 594                 NaN
# 595                 NaN
#
# [596 rows x 42 columns]

# %%
land_zone = gls[["land_parcel", "zone_guess"]]
gls = pd.merge(gls, zone_region, how="left", left_on="zone_guess", right_on="zone")
# region_na = merged_region[merged_region.region.isna()]
# region_na
gls.rename(columns={'zone': 'zone_by_land_parcel', 'region': 'region_by_land_parcel'}, inplace=True)
gls
# Out:
#                                              sg_gls_id date_launch  \
# 0    8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 1    f2e43515a8e783bc2314727cb58587c8ee761ab7a4a016...   29/4/2015
# 2    384815dd4cafcbf88b2f11099d8bced7a584736ec36742...  30/12/2013
# 3    05c11060bf1cbcb2db7aa3ed898c19a09fd298c3b1c3a4...   15/4/2013
# 4    d9fcb7d323ca5b77f6a22635200afafdd99e67f6feb109...   28/2/2013
# ..                                                 ...         ...
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...  19/10/1992
# 592  40e8902a48c5f3b717a76c37e270d2360da9e1172da322...  19/10/1992
# 593  43e84a0ed4744cddede5fb08c7162e61eb86cdf7b7823d...  19/10/1992
# 594  473d6c80a232fc34e07f2a9ef544b66270d175537468eb...   31/8/1992
# 595  50895000069c66ef0605e7f5fc87b07ecbbb602ea102ff...   31/8/1992
#
#      date_close date_award                              land_parcel  \
# 0     23/6/2015  30/6/2015                           Queenstown S9b
# 1     18/6/2015  23/6/2015                             Toa Payoh S4
# 2     29/4/2014  30/4/2014                               Geylang S6
# 3     13/6/2013  14/6/2013                             Sengkang S12
# 4     11/4/2013  12/4/2013                             Sengkang S11
# ..          ...        ...                                      ...
# 591    9/2/1993  21/5/1993                               Kaki Bukit
# 592    9/2/1993  21/5/1993  Tuas South Avenue 3/Tuas South Avenue 4
# 593    9/2/1993  21/5/1993  Tuas South Avenue 4/Tuas South Avenue 5
# 594  24/11/1992  15/2/1993               Merchant Road/Angus Street
# 595  24/11/1992  15/2/1993              Merchant Road/Magazine Road
#
#                             zone_formatted  zone_guess  \
# 0                               queenstown  queenstown
# 1                                toa payoh   toa payoh
# 2                                  geylang     geylang
# 3                                 sengkang    sengkang
# 4                                 sengkang    sengkang
# ..                                     ...         ...
# 591                                   kaki         NaN
# 592  tuas south avenue 3/tuas south avenue         NaN
# 593  tuas south avenue 4/tuas south avenue         NaN
# 594                    merchant road/angus         NaN
# 595                 merchant road/magazine         NaN
#
#                                       street  site_area_sqm   devt_type  ...  \
# 0                                Dundee Road        10516.1         *CO  ...
# 1      Lorong 6 Toa Payoh/Lorong 4 Toa Payoh        12154.6         *CO  ...
# 2                                 Sims Drive        23900.1         *CO  ...
# 3                             Fernvale Close        14930.5         *CO  ...
# 4                          Sengkang West Way        16603.9         *CO  ...
# ..                                       ...            ...         ...  ...
# 591                               Kaki Bukit        60000.0  Industrial  ...
# 592  Tuas South Avenue 3/Tuas South Avenue 4       102264.0  Industrial  ...
# 593  Tuas South Avenue 4/Tuas South Avenue 5       102264.0  Industrial  ...
# 594               Merchant Road/Angus Street         2609.0       Hotel  ...
# 595              Merchant Road/Magazine Road         4806.0  Commercial  ...
#
#     award_month_index  year_award  month_award  day_award  \
# 0              201506        2015            6         30
# 1              201506        2015            6         23
# 2              201404        2014            4         30
# 3              201306        2013            6         14
# 4              201304        2013            4         12
# ..                ...         ...          ...        ...
# 591            199305        1993            5         21
# 592            199305        1993            5         21
# 593            199305        1993            5         21
# 594            199302        1993            2         15
# 595            199302        1993            2         15
#
#               project_name     region_by_proj zone_by_proj  \
# 0              queens-peak     central region   queenstown
# 1           gem-residences     central region    toa payoh
# 2         sims-urban-oasis     central region      geylang
# 3    rivertrees-residences  north-east region     sengkang
# 4    riverbank-at-fernvale  north-east region     sengkang
# ..                     ...                ...          ...
# 591                    NaN                NaN          NaN
# 592                    NaN                NaN          NaN
# 593                    NaN                NaN          NaN
# 594                    NaN                NaN          NaN
# 595                    NaN                NaN          NaN
#
#          address_street  zone_by_land_parcel region_by_land_parcel
# 0           dundee road           queenstown        central region
# 1    lorong 5 toa payoh            toa payoh        central region
# 2            sims drive              geylang        central region
# 3        fernvale close             sengkang     north-east region
# 4        fernvale close             sengkang     north-east region
# ..                  ...                  ...                   ...
# 591                 NaN                  NaN                   NaN
# 592                 NaN                  NaN                   NaN
# 593                 NaN                  NaN                   NaN
# 594                 NaN                  NaN                   NaN
# 595                 NaN                  NaN                   NaN
#
# [596 rows x 44 columns]

# %% [markdown]
# ## Try using street name

# %%
gls[(gls.zone_by_land_parcel.isna()) & (gls.zone_by_land_parcel.isna())]
# Out:
#                                              sg_gls_id date_launch  \
# 90   28a4504a5ccbb82851214a73f5654bb8b27dddde3b01ff...   26/8/1994
# 95   46f27a2ed3f4b06d2e7c555c2f9866dba9929bc73a2f22...   25/2/1994
# 96   778c2cc437d91d18db23819250da67a91744843be70d6c...   13/8/1993
# 97   c1ee0b83a5ca26200826d9f25a6824abff2214cb0cf4b5...   13/8/1993
# 98   631f75552be42de32da7caa2235c23a82a02e29a5cf175...   13/8/1993
# ..                                                 ...         ...
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...  19/10/1992
# 592  40e8902a48c5f3b717a76c37e270d2360da9e1172da322...  19/10/1992
# 593  43e84a0ed4744cddede5fb08c7162e61eb86cdf7b7823d...  19/10/1992
# 594  473d6c80a232fc34e07f2a9ef544b66270d175537468eb...   31/8/1992
# 595  50895000069c66ef0605e7f5fc87b07ecbbb602ea102ff...   31/8/1992
#
#      date_close date_award                              land_parcel  \
# 90   27/10/1994  9/12/1994                              Bt Batok S2
# 95    28/4/1994  19/8/1994                            Bt Panjang S1
# 96   14/10/1993  21/1/1994                              Bt Merah S4
# 97   14/10/1993  21/1/1994                            Bt Panjang S2
# 98   14/10/1993  21/1/1994                              Bt Batok S3
# ..          ...        ...                                      ...
# 591    9/2/1993  21/5/1993                               Kaki Bukit
# 592    9/2/1993  21/5/1993  Tuas South Avenue 3/Tuas South Avenue 4
# 593    9/2/1993  21/5/1993  Tuas South Avenue 4/Tuas South Avenue 5
# 594  24/11/1992  15/2/1993               Merchant Road/Angus Street
# 595  24/11/1992  15/2/1993              Merchant Road/Magazine Road
#
#                             zone_formatted zone_guess  \
# 90                                bt batok        NaN
# 95                              bt panjang        NaN
# 96                                bt merah        NaN
# 97                              bt panjang        NaN
# 98                                bt batok        NaN
# ..                                     ...        ...
# 591                                   kaki        NaN
# 592  tuas south avenue 3/tuas south avenue        NaN
# 593  tuas south avenue 4/tuas south avenue        NaN
# 594                    merchant road/angus        NaN
# 595                 merchant road/magazine        NaN
#
#                                       street  site_area_sqm   devt_type  ...  \
# 90                       Bt Batok East Ave 3        50000.0          LP  ...
# 95                                  Petir Rd        25000.0          AP  ...
# 96                   Tanglin Rd/Alexandra Rd        10542.1          CO  ...
# 97                                  Petir Rd        58838.3       BH/LP  ...
# 98                       Bt Batok East Ave 3        25000.0          AP  ...
# ..                                       ...            ...         ...  ...
# 591                               Kaki Bukit        60000.0  Industrial  ...
# 592  Tuas South Avenue 3/Tuas South Avenue 4       102264.0  Industrial  ...
# 593  Tuas South Avenue 4/Tuas South Avenue 5       102264.0  Industrial  ...
# 594               Merchant Road/Angus Street         2609.0       Hotel  ...
# 595              Merchant Road/Magazine Road         4806.0  Commercial  ...
#
#     award_month_index  year_award  month_award  day_award     project_name  \
# 90             199412        1994           12          9              NaN
# 95             199408        1994            8         19       maysprings
# 96             199401        1994            1         21  tanglin-regency
# 97             199401        1994            1         21              NaN
# 98             199401        1994            1         21              NaN
# ..                ...         ...          ...        ...              ...
# 591            199305        1993            5         21              NaN
# 592            199305        1993            5         21              NaN
# 593            199305        1993            5         21              NaN
# 594            199302        1993            2         15              NaN
# 595            199302        1993            2         15              NaN
#
#      region_by_proj   zone_by_proj  address_street  zone_by_land_parcel  \
# 90              NaN            NaN             NaN                  NaN
# 95      west region  bukit panjang      petir road                  NaN
# 96   central region    bukit merah    tanglin road                  NaN
# 97              NaN            NaN             NaN                  NaN
# 98              NaN            NaN             NaN                  NaN
# ..              ...            ...             ...                  ...
# 591             NaN            NaN             NaN                  NaN
# 592             NaN            NaN             NaN                  NaN
# 593             NaN            NaN             NaN                  NaN
# 594             NaN            NaN             NaN                  NaN
# 595             NaN            NaN             NaN                  NaN
#
#     region_by_land_parcel
# 90                    NaN
# 95                    NaN
# 96                    NaN
# 97                    NaN
# 98                    NaN
# ..                    ...
# 591                   NaN
# 592                   NaN
# 593                   NaN
# 594                   NaN
# 595                   NaN
#
# [333 rows x 44 columns]

# %%
# clean street names, remove numbers, punctuations; trans to lower case, remove suffix

# pattern = r'\d+'
# text = "clementi ave .22"
# suffix = ['street', 'st', 'road', 'rd', 'avenue', 'ave', 'crescent', 'drive', 'dr', 'boulevard', 'blvd', 'rise', 'way', 'lane', 'alley', 'link', 'walk', 'vista', 'track', 'vale']
# prefix = ['upper', 'lower']
# news = ['north', 'east', 'west', 'north']
# rm_num = re.sub(pattern, '', text)
# rm_punc = ''.join([char for char in list(rm_num) if char not in string.punctuation])
# rm_punc

geo["cleaned_st"] = geo.address_street.apply(clean_street_name)
gls.insert(loc=list(gls.columns).index("street")+1, column="cleaned_st", value=gls.street.apply(clean_street_name))
gls[["street", "cleaned_st"]]
# Out:
#                                       street  \
# 0                                Dundee Road
# 1      Lorong 6 Toa Payoh/Lorong 4 Toa Payoh
# 2                                 Sims Drive
# 3                             Fernvale Close
# 4                          Sengkang West Way
# ..                                       ...
# 591                               Kaki Bukit
# 592  Tuas South Avenue 3/Tuas South Avenue 4
# 593  Tuas South Avenue 4/Tuas South Avenue 5
# 594               Merchant Road/Angus Street
# 595              Merchant Road/Magazine Road
#
#                             cleaned_st
# 0                               dundee
# 1    lorong toa payoh lorong toa payoh
# 2                                 sims
# 3                       fernvale close
# 4                             sengkang
# ..                                 ...
# 591                         kaki bukit
# 592       tuas south avenue tuas south
# 593       tuas south avenue tuas south
# 594                merchant road angus
# 595             merchant road magazine
#
# [596 rows x 2 columns]

# %%
street_ref = geo[["cleaned_st", "zone", "region"]]
street_ref = street_ref.drop_duplicates(subset='cleaned_st')
# gls = pd.merge(gls, street_ref, how='left', left_on='cleaned_st', right_on='cleaned_st')
st_name_list = list(gls.cleaned_st)
st_name_ref = list(street_ref.cleaned_st)
# zone_by_st = [street_ref.zone[street_ref.cleaned_st.str.contains(name)] for name in st_name_list
gls["st_guess"] = gls.cleaned_st.apply(st_name_match, ref_df=street_ref, key="cleaned_st")
gls = pd.merge(gls, street_ref, how='left', left_on='st_guess', right_on='cleaned_st').drop(["cleaned_st_x", "cleaned_st_y"], axis=1)

# %%
gls.rename(columns={"zone": "zone_by_st", "region": "region_by_st"}, inplace=True)
gls[["land_parcel", "street", "st_guess", "zone_by_st", "region_by_st"]]
# Out:
#                                  land_parcel  \
# 0                             Queenstown S9b
# 1                               Toa Payoh S4
# 2                                 Geylang S6
# 3                               Sengkang S12
# 4                               Sengkang S11
# ..                                       ...
# 591                               Kaki Bukit
# 592  Tuas South Avenue 3/Tuas South Avenue 4
# 593  Tuas South Avenue 4/Tuas South Avenue 5
# 594               Merchant Road/Angus Street
# 595              Merchant Road/Magazine Road
#
#                                       street          st_guess  \
# 0                                Dundee Road            dundee
# 1      Lorong 6 Toa Payoh/Lorong 4 Toa Payoh  lorong toa payoh
# 2                                 Sims Drive              sims
# 3                             Fernvale Close    fernvale close
# 4                          Sengkang West Way          sengkang
# ..                                       ...               ...
# 591                               Kaki Bukit        kaki bukit
# 592  Tuas South Avenue 3/Tuas South Avenue 4        tuas south
# 593  Tuas South Avenue 4/Tuas South Avenue 5        tuas south
# 594               Merchant Road/Angus Street          merchant
# 595              Merchant Road/Magazine Road          merchant
#
#           zone_by_st       region_by_st
# 0         queenstown     central region
# 1          toa payoh     central region
# 2            geylang     central region
# 3           sengkang  north-east region
# 4           sengkang  north-east region
# ..               ...                ...
# 591            bedok        east region
# 592             tuas        west region
# 593             tuas        west region
# 594  singapore river     central region
# 595  singapore river     central region
#
# [596 rows x 5 columns]

# %%
gls[gls.sg_gls_id=='2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c556b20932d6962e3586']
# Out:
#                                              sg_gls_id date_launch date_close  \
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...  19/10/1992   9/2/1993
#
#     date_award land_parcel zone_formatted zone_guess      street  \
# 591  21/5/1993  Kaki Bukit           kaki        NaN  Kaki Bukit
#
#      site_area_sqm   devt_type  ... day_award  project_name  region_by_proj  \
# 591        60000.0  Industrial  ...        21           NaN             NaN
#
#      zone_by_proj  address_street  zone_by_land_parcel region_by_land_parcel  \
# 591           NaN             NaN                  NaN                   NaN
#
#        st_guess  zone_by_st region_by_st
# 591  kaki bukit       bedok  east region
#
# [1 rows x 47 columns]

# %% [markdown]
# ## Combine results to one column

# %%
zone_region_cols = gls[["zone_by_proj", "zone_by_land_parcel", "zone_by_st", "region_by_proj", "region_by_land_parcel", "region_by_st"]]
zone_region_cols
# Out:
#     zone_by_proj zone_by_land_parcel       zone_by_st     region_by_proj  \
# 0     queenstown          queenstown       queenstown     central region
# 1      toa payoh           toa payoh        toa payoh     central region
# 2        geylang             geylang          geylang     central region
# 3       sengkang            sengkang         sengkang  north-east region
# 4       sengkang            sengkang         sengkang  north-east region
# ..           ...                 ...              ...                ...
# 591          NaN                 NaN            bedok                NaN
# 592          NaN                 NaN             tuas                NaN
# 593          NaN                 NaN             tuas                NaN
# 594          NaN                 NaN  singapore river                NaN
# 595          NaN                 NaN  singapore river                NaN
#
#     region_by_land_parcel       region_by_st
# 0          central region     central region
# 1          central region     central region
# 2          central region     central region
# 3       north-east region  north-east region
# 4       north-east region  north-east region
# ..                    ...                ...
# 591                   NaN        east region
# 592                   NaN        west region
# 593                   NaN        west region
# 594                   NaN     central region
# 595                   NaN     central region
#
# [596 rows x 6 columns]

# %%
zone = []
region = []
join_by = []
check = []
discrepancy = []
for i in range(zone_region_cols.shape[0]):
    if pd.notna(zone_region_cols.zone_by_proj[i]):
        zone.append(zone_region_cols.zone_by_proj[i])
        join_by.append('project name')
    elif pd.notna(zone_region_cols.zone_by_st[i]):
        zone.append(zone_region_cols.zone_by_st[i])
        join_by.append('street name')
    elif pd.notna(zone_region_cols.zone_by_land_parcel[i]):
        zone.append(zone_region_cols.zone_by_land_parcel[i])
        join_by.append('land parcel/zone')
    else:
        zone.append(np.nan)
        join_by.append(np.nan)
    check = [item for item in [zone_region_cols.zone_by_proj[i], zone_region_cols.zone_by_st[i], zone_region_cols.zone_by_land_parcel[i]] if pd.notna(item)]
    if len(check)<=1:
        discrepancy.append('poor matched')
    elif len(set(check))>1:
        discrepancy.append('multiple matched')
    else:
        discrepancy.append(0)

    if pd.notna(zone_region_cols.region_by_proj[i]):
        region.append(zone_region_cols.region_by_proj[i])
    elif pd.notna(zone_region_cols.region_by_st[i]):
        region.append(zone_region_cols.region_by_st[i])
    elif pd.notna(zone_region_cols.region_by_land_parcel[i]):
        region.append(zone_region_cols.region_by_land_parcel[i])
    else:
        region.append(np.nan)

# %%
gls.insert(loc=list(header_gls).index("street")+1, column='error_check', value=discrepancy)
gls.insert(loc=list(header_gls).index("street")+1, column='join_by', value=join_by)
gls.insert(loc=list(header_gls).index("street")+1, column='region', value=region)
gls.insert(loc=list(header_gls).index("street")+1, column='zone', value=zone)

# %%
gls_check = gls[["sg_gls_id", "proj_name_res", "land_parcel",
                 "street", "zone_by_proj", "zone_by_land_parcel",
                 "zone_by_st", "region_by_proj", "region_by_land_parcel",
                 "region_by_st", "error_check", "join_by", "region", "zone"]]
gls_check[gls_check.sg_gls_id=='2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c556b20932d6962e3586']
# Out:
#                                              sg_gls_id proj_name_res  \
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...           NaN
#
#     land_parcel      street zone_by_proj zone_by_land_parcel zone_by_st  \
# 591  Kaki Bukit  Kaki Bukit          NaN                 NaN      bedok
#
#     region_by_proj region_by_land_parcel region_by_st   error_check  \
# 591            NaN                   NaN  east region  poor matched
#
#          join_by       region   zone
# 591  street name  east region  bedok

# %% [markdown]
# ## Export matched table

# %%
new_header = header_gls[:6]+["zone","region","join_by","error_check"]+header_gls[6:]
gls_output = gls[new_header]
# gls_output.to_csv("gls_full_loc_filled.csv", header=True, index=False)

# %% [markdown]
# # Fill in tenderer details HDB

# %%
gls = pd.read_csv("gls_full_loc_filled.csv")
gls.rename(columns={"tenderer_name": "successful_tenderer_name", "tender_price": "successful_tender_price", "price_psm_gfa": "successful_price_psm_gfa"}, inplace=True)
gls.drop('tenderer_rank', axis=1, inplace=True)
gls
# Out:
#                                              sg_gls_id date_launch  \
# 0    8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 1    f2e43515a8e783bc2314727cb58587c8ee761ab7a4a016...   29/4/2015
# 2    384815dd4cafcbf88b2f11099d8bced7a584736ec36742...  30/12/2013
# 3    05c11060bf1cbcb2db7aa3ed898c19a09fd298c3b1c3a4...   15/4/2013
# 4    d9fcb7d323ca5b77f6a22635200afafdd99e67f6feb109...   28/2/2013
# ..                                                 ...         ...
# 591  2b49a7c56443c8359c7d541c2f8c44889120a0b497d9c5...  19/10/1992
# 592  40e8902a48c5f3b717a76c37e270d2360da9e1172da322...  19/10/1992
# 593  43e84a0ed4744cddede5fb08c7162e61eb86cdf7b7823d...  19/10/1992
# 594  473d6c80a232fc34e07f2a9ef544b66270d175537468eb...   31/8/1992
# 595  50895000069c66ef0605e7f5fc87b07ecbbb602ea102ff...   31/8/1992
#
#      date_close date_award                              land_parcel  \
# 0     23/6/2015  30/6/2015                           Queenstown S9b
# 1     18/6/2015  23/6/2015                             Toa Payoh S4
# 2     29/4/2014  30/4/2014                               Geylang S6
# 3     13/6/2013  14/6/2013                             Sengkang S12
# 4     11/4/2013  12/4/2013                             Sengkang S11
# ..          ...        ...                                      ...
# 591    9/2/1993  21/5/1993                               Kaki Bukit
# 592    9/2/1993  21/5/1993  Tuas South Avenue 3/Tuas South Avenue 4
# 593    9/2/1993  21/5/1993  Tuas South Avenue 4/Tuas South Avenue 5
# 594  24/11/1992  15/2/1993               Merchant Road/Angus Street
# 595  24/11/1992  15/2/1993              Merchant Road/Magazine Road
#
#                                       street             zone  \
# 0                                Dundee Road       queenstown
# 1      Lorong 6 Toa Payoh/Lorong 4 Toa Payoh        toa payoh
# 2                                 Sims Drive          geylang
# 3                             Fernvale Close         sengkang
# 4                          Sengkang West Way         sengkang
# ..                                       ...              ...
# 591                               Kaki Bukit            bedok
# 592  Tuas South Avenue 3/Tuas South Avenue 4             tuas
# 593  Tuas South Avenue 4/Tuas South Avenue 5             tuas
# 594               Merchant Road/Angus Street  singapore river
# 595              Merchant Road/Magazine Road  singapore river
#
#                 region       join_by   error_check  ...  month_launch  \
# 0       central region  project name             0  ...             4
# 1       central region  project name             0  ...             4
# 2       central region  project name             0  ...            12
# 3    north-east region  project name             0  ...             4
# 4    north-east region  project name             0  ...             2
# ..                 ...           ...           ...  ...           ...
# 591        east region   street name  poor matched  ...            10
# 592        west region   street name  poor matched  ...            10
# 593        west region   street name  poor matched  ...            10
# 594     central region   street name  poor matched  ...             8
# 595     central region   street name  poor matched  ...             8
#
#     day_launch close_month_index  year_close  month_close  day_close  \
# 0           29            201506        2015            6         23
# 1           29            201506        2015            6         18
# 2           30            201404        2014            4         29
# 3           15            201306        2013            6         13
# 4           28            201304        2013            4         11
# ..         ...               ...         ...          ...        ...
# 591         19            199302        1993            2          9
# 592         19            199302        1993            2          9
# 593         19            199302        1993            2          9
# 594         31            199211        1992           11         24
# 595         31            199211        1992           11         24
#
#      award_month_index year_award  month_award  day_award
# 0               201506       2015            6         30
# 1               201506       2015            6         23
# 2               201404       2014            4         30
# 3               201306       2013            6         14
# 4               201304       2013            4         12
# ..                 ...        ...          ...        ...
# 591             199305       1993            5         21
# 592             199305       1993            5         21
# 593             199305       1993            5         21
# 594             199302       1993            2         15
# 595             199302       1993            2         15
#
# [596 rows x 39 columns]

# %%
tender_details = pd.read_csv("hdb_tenderer_details.csv")
list(tender_details.columns)
# Out:
# ['land_parcel_std',
#  'tenderer_rank',
#  'tenderer_name',
#  'tender_price',
#  'tender_price_text']

# %% [markdown]
# ### Align land parcel names

# %%
unique_land_details = pd.Series(tender_details.land_parcel.unique()).reset_index(drop=True)

# %%
unique_land_gls = pd.Series(gls[gls.source=='hdb'].land_parcel.unique()).reset_index(drop=True)

# %%
name_match('Ang Mok Kio S6', unique_land_details)
align_names = pd.DataFrame({'original': unique_land_gls, 'aligned': unique_land_gls.apply(name_match, dictionary=unique_land_details)})

# %%
align_names['ori_name'] = align_names.original.apply(lambda x: ' '.join(x.split(' ')[:-1]))
align_names['parcel_code'] = align_names.original.apply(lambda x: x.split(' ')[-1])
align_names['aligned'] = align_names.ori_name.apply(name_match, dictionary = unique_land_details.apply(lambda x: ' '.join(x.split(' ')[:-1])))
align_names = align_names[['ori_name', 'parcel_code', 'aligned', 'original']]

# %%
bt_idx = align_names[align_names.ori_name.str.contains('Bt')].index
align_names.iloc[bt_idx, 0] = align_names.iloc[bt_idx, 0].apply(lambda x: x.replace('Bt', 'Bukit'))
align_names['aligned'] = align_names.ori_name.apply(name_match, dictionary=unique_land_details.apply(lambda x: ' '.join(x.split(' ')[:-1])))
align_names['name_repl'] = align_names.aligned.apply(lambda x: x[0]) + ' ' + align_names.parcel_code

# %%
name_replace = align_names[['original', 'name_repl']]
name_replace.rename(columns={'original': 'land_parcel'}, inplace=True)
name_replace
# Out:
# e:\Anaconda3\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#         land_parcel       name_repl
# 0    Queenstown S9b  Queenstown S9b
# 1      Toa Payoh S4    Toa Payoh S4
# 2        Geylang S6      Geylang S6
# 3      Sengkang S12    Sengkang S12
# 4      Sengkang S11    Sengkang S11
# ..              ...             ...
# 200   Sengkang N1NC   Sengkang N1NC
# 201    Sembawang P1    Sembawang P1
# 202  Woodlands N4NC  Woodlands N4NC
# 203    Hougang N9NC    Hougang N9NC
# 204    Hougang N5NC    Hougang N5NC
#
# [205 rows x 2 columns]

# %%
# replace names
gls.insert(loc=5, column='land_parcel_std', value=pd.merge(gls, name_replace, on='land_parcel').name_repl)

# %%
# gls.to_csv(r'G:\REA\Working files\land-bidding\land_sales_full_data\ready for uploading\gls_no_detail_v2.csv', index=False)

# %% [markdown]
# ### Merge tenderer details

# %%
gls_details = pd.merge(gls[gls.source=='hdb'], tender_details, how='left', on='land_parcel_std')
gls_details[gls_details.tenderer_rank.isna()]
# Out:
# Empty DataFrame
# Columns: [sg_gls_id, date_launch, date_close, date_award, land_parcel, land_parcel_std, street, zone, region, join_by, error_check, site_area_sqm, devt_type, devt_class, lease_term, gpr, gfa_sqm, num_bidders, successful_tenderer_name, successful_tender_price, successful_price_psm_gfa, proj_name_raw, proj_name_res, proj_name_non_res, source, timediff_launch_to_close, timediff_close_to_award, timediff_launch_to_award, launch_month_index, year_launch, month_launch, day_launch, close_month_index, year_close, month_close, day_close, award_month_index, year_award, month_award, day_award, tenderer_rank, tenderer_name, tender_price, tender_price_text]
# Index: []
#
# [0 rows x 44 columns]

# %%
gls_details['price_psm_gfa'] = gls_details.tender_price / gls_details.gfa_sqm
gls_details['price_psm_gfa'] = gls_details.price_psm_gfa.apply(lambda x: '%.2f' %x)
gls_details
# Out:
#                                               sg_gls_id date_launch  \
# 0     8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 1     8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 2     8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 3     8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# 4     8c101477584713a9310e02940aac6b059e37833ab6848d...   29/4/2015
# ...                                                 ...         ...
# 1442  99b11f1948b4fc3e79bba927f654f433a5a55d2dff7c1e...   28/7/1995
# 1443  7f55fed1fc42dd52d24742b2c93ed9b9d36bc65deeedbb...   25/2/1994
# 1444  7f55fed1fc42dd52d24742b2c93ed9b9d36bc65deeedbb...   25/2/1994
# 1445  7f55fed1fc42dd52d24742b2c93ed9b9d36bc65deeedbb...   25/2/1994
# 1446  7f55fed1fc42dd52d24742b2c93ed9b9d36bc65deeedbb...   25/2/1994
#
#      date_close  date_award     land_parcel land_parcel_std  \
# 0     23/6/2015   30/6/2015  Queenstown S9b  Queenstown S9b
# 1     23/6/2015   30/6/2015  Queenstown S9b  Queenstown S9b
# 2     23/6/2015   30/6/2015  Queenstown S9b  Queenstown S9b
# 3     23/6/2015   30/6/2015  Queenstown S9b  Queenstown S9b
# 4     23/6/2015   30/6/2015  Queenstown S9b  Queenstown S9b
# ...         ...         ...             ...             ...
# 1442  28/9/1995  30/11/1995    Hougang N9NC    Hougang N9NC
# 1443  28/4/1994   19/8/1994    Hougang N5NC    Hougang N5NC
# 1444  28/4/1994   19/8/1994    Hougang N5NC    Hougang N5NC
# 1445  28/4/1994   19/8/1994    Hougang N5NC    Hougang N5NC
# 1446  28/4/1994   19/8/1994    Hougang N5NC    Hougang N5NC
#
#                             street        zone             region  \
# 0                      Dundee Road  queenstown     central region
# 1                      Dundee Road  queenstown     central region
# 2                      Dundee Road  queenstown     central region
# 3                      Dundee Road  queenstown     central region
# 4                      Dundee Road  queenstown     central region
# ...                            ...         ...                ...
# 1442              Hougang Avenue 9     hougang  north-east region
# 1443  Hougang St 51/Buangkok Green     hougang  north-east region
# 1444  Hougang St 51/Buangkok Green     hougang  north-east region
# 1445  Hougang St 51/Buangkok Green     hougang  north-east region
# 1446  Hougang St 51/Buangkok Green     hougang  north-east region
#
#            join_by  ... day_close  award_month_index year_award month_award  \
# 0     project name  ...        23             201506       2015           6
# 1     project name  ...        23             201506       2015           6
# 2     project name  ...        23             201506       2015           6
# 3     project name  ...        23             201506       2015           6
# 4     project name  ...        23             201506       2015           6
# ...            ...  ...       ...                ...        ...         ...
# 1442   street name  ...        28             199511       1995          11
# 1443  project name  ...        28             199408       1994           8
# 1444  project name  ...        28             199408       1994           8
# 1445  project name  ...        28             199408       1994           8
# 1446  project name  ...        28             199408       1994           8
#
#       day_award  tenderer_rank  \
# 0            30              1
# 1            30              2
# 2            30              3
# 3            30              4
# 4            30              5
# ...         ...            ...
# 1442         30              7
# 1443         19              1
# 1444         19              2
# 1445         19              3
# 1446         19              4
#
#                                           tenderer_name  tender_price  \
# 0                                     HY Realty Pte Ltd   483178000.0
# 1                           Allgreen Properties Limited   445910000.0
# 2     Intrepid Investments Pte Ltd, Verwood \nHoldin...   432774525.0
# 3     FCL Tampines Court Pte. Ltd. and KH Capital \n...   421500000.0
# 4     UOL Venture Investments Pte. Ltd., Singland \n...   417280000.0
# ...                                                 ...           ...
# 1442                      Silverdale Investment Pte Ltd    21000000.0
# 1443                          Hiap Hoe Holdings Pte ltd    38800000.0
# 1444               Far East Organization Centre Pte Ltd    34390000.0
# 1445  United Industrial Corporation \nLtd/Shenton Ho...    26888000.0
# 1446                              Wing Tai Land Pte Ltd    18000000.0
#
#      tender_price_text  price_psm_gfa
# 0       483,178,000.00        9376.84
# 1       445,910,000.00        8653.59
# 2       432,774,525.00        8398.68
# 3       421,500,000.00        8179.88
# 4       417,280,000.00        8097.98
# ...                ...            ...
# 1442     21,000,000.00        1129.03
# 1443     38,800,000.00        1949.75
# 1444     34,390,000.00        1728.14
# 1445     26,888,000.00        1351.16
# 1446     18,000,000.00         904.52
#
# [1447 rows x 45 columns]

# %%
gls_details = pd.read_csv(r'G:\REA\Working files\land-bidding\land_sales_full_data\ready for uploading\gls_hdb_details_filled.csv')
groupby = pd.DataFrame(gls_details.groupby('land_parcel_std').count()['land_parcel']).reset_index()
# gls_details.to_csv("gls_hdb_details_filled.csv", index=False)
check = pd.merge(gls_details[['land_parcel_std', 'num_bidders']], groupby, on='land_parcel_std')
check['diff'] = check.num_bidders - check.land_parcel
check
# Out:
#      land_parcel_std  num_bidders  land_parcel  diff
# 0     Queenstown S9b            9            9     0
# 1     Queenstown S9b            9            9     0
# 2     Queenstown S9b            9            9     0
# 3     Queenstown S9b            9            9     0
# 4     Queenstown S9b            9            9     0
# ...              ...          ...          ...   ...
# 1442    Hougang N9NC            7            7     0
# 1443    Hougang N5NC            4            4     0
# 1444    Hougang N5NC            4            4     0
# 1445    Hougang N5NC            4            4     0
# 1446    Hougang N5NC            4            4     0
#
# [1447 rows x 4 columns]

# %%
gls_details_only = gls_details[['sg_gls_id', 'land_parcel_std', 'tenderer_rank', 'tenderer_name', 'tender_price', 'tender_price_text', 'price_psm_gfa']]
gls_details_only.to_csv(r'G:\REA\Working files\land-bidding\land_sales_full_data\ready for uploading\gls_details_only.csv', index=False)
